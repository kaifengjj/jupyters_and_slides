# %%
import requests
import collections
headers = {"User-Agent" : "User-Agent:Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;"}
url='https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485'
r = requests.get(url, headers=headers).content.decode('utf8')

# %%
file=open('soucepage.txt','w+')

# %%
file.write(r)
# Out:
# 333759

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r, 'html.parser')

# %%
all_lines=[]
all_lines_url=[]
table=soup.find('table',attrs={'width':'658'})
lines=table.find_all('a')
for line in lines:
    all_lines.append(line.string)
    all_lines_url.append(line.get('href'))
all_lines.pop()
all_lines_url.pop()
print(all_lines)
print(all_lines_url)
# Out:
# ['北京地铁1号线', '北京地铁2号线', '北京地铁4号线', '北京地铁5号线', '北京地铁6号线', '北京地铁7号线', '北京地铁8号线', '北京地铁9号线', '北京地铁10号线', '北京地铁13号线', '北京地铁14号线', '北京地铁14号线', '北京地铁15号线', '北京地铁16号线', '北京地铁八通线', '北京地铁昌平线', '北京地铁亦庄线', '北京地铁房山线']
# ...

# %%
from urllib.parse import urljoin
#相对路径转绝对路径
def absolute_urls(relative_url):
    return urljoin(url,relative_url)

# %%
def get_source_page_html(urls):
    headers = {"User-Agent" : "User-Agent:Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;"}
    return requests.get(urls,headers).content.decode('utf-8')

# %%
r_one=requests.get(lineonepage,headers=headers).content.decode("utf-8")

# %%
r_one
# Out:
# '<!DOCTYPE html>\n<!--STATUS OK-->\n<html>\n\n\n\n<head>\n<meta charset="UTF-8">\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<meta name="referrer" content="always" />\n<meta name="description" content="北京地铁昌平线（以下简称“昌平线”），是连接北京市区与北部昌平新城的地铁线路。由北京市地铁运营有限公司第四分公司负责运营。一期于2010年12月30日开通；二期于2015年12月26日开通。一期由西二旗开往南邵 二期由南邵开往昌平西山口。截至2015年12月26日，该线运营区段为西二旗站至昌平西山口站，途经海淀区和昌平区，运营里程31.9千米，共开放12座车站（其中换乘车站2座），拥有车辆基地2座（定泗路停车场、十三陵景区车辆段）。...">\n<title>北京地铁昌平线_百度百科</title>\n<link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\n<link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu.svg">\n\n<meta name="keywords" content="北京地铁昌平线 地铁北京昌平线 昌平地铁 北京昌平地铁线 北京昌平线地铁 昌平线地铁 北京昌平线 昌平地铁线 昌平线 北京地铁昌平线历史沿革 北京地铁昌平线运营信息 北京地铁昌平线硬件设施 北京地铁昌平线延长规划 北京地铁昌平线线路标识 北京地铁昌平线管理机构 北京地铁昌平线票价规定 北京地铁昌平线建设意义">\n<meta name="image" content="https://bkssl.bdimg.com/cms/static/baike.png">\n<script type="text/javascript">\r\n  // 配置 PD 监控。\r\n  window.alogObjectConfig = {\r\n    product: \'103\',\r\n    pag
# ...

# %%
def list_stations(each_line_souce_page):
    soup=BeautifulSoup(each_line_souce_page,'html.parser')
    eachline_stations=[]
    x=soup1.find('table',attrs={'data-sort':'sortDisabled'})
    stationlist=x.find_all('a')
    for i in stationlist:
        if i.string[-1] =='站':
            eachline_stations.append(i.string)
    return eachline_stations

# %%
soup1=BeautifulSoup(r_one,'html.parser')

# %%
lista=[]
x=soup1.find('table',attrs={'data-sort':'sortDisabled'})
stationlist=x.find_all('a')
for i in stationlist:
    if i.string[-1] =='站':
       lista.append(i.string)
lista
# Out:
# ['西二旗站',
#  '生命科学园站',
#  '朱辛庄站',
#  '巩华城站',
#  '沙河站',
#  '沙河高教园站',
#  '南邵站',
#  '北邵洼站',
#  '昌平东关站',
#  '昌平站',
#  '昌平北站',
#  '十三陵景区站',
#  '昌平西山口站']

# %%
def find_lines_with_stations():
    lines_and_stations=collections.defaultdict(list)
    url='https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485'
    soup = BeautifulSoup(get_source_page_html(url), 'html.parser')
    table=soup.find('table',attrs={'width':'658'})
    lines=table.find_all('a')
    for line in lines:
        lines_and_stations[line.string]=list_stations(get_source_page_html(absolute_urls(line.get('href'))))                     
                             
                             
    all_lines.pop()
    all_lines_url.pop()
    
    for i in all_lines:
        lines_and_stations[i]=
    
    
    lines_and_stations[line]=stations
    return lines_and_stations
